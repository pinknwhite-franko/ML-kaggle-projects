# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/hayleyluo/Desktop/Github/ML-kaggle-on-the-snow-ski-area-reviews/skireview/bin/python -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/hayleyluo/Desktop/Github/ML-kaggle-on-the-snow-ski-area-reviews/skireview/bin/python -m pip install --upgrade pip' command.

# %%
import os 
import pandas as pd
import numpy as np

# %%
# Get the current directory
current_directory = os.getcwd()

print(f"current directory: {current_directory}")
# Out:
# current directory: /Users/hayleyluo/Desktop/Github/ML-kaggle-on-the-snow-ski-area-reviews

# %%
file = f"{current_directory}/datasets/fredkellner/onthesnow-ski-area-reviews/versions/1/OnTheSnow_SkiAreaReviews.csv"

# %%
df = pd.read_csv(file, header=0)
df
# Out:
#        Unnamed: 0          State            Ski Area  Reviewer Name  \
# 0               0     california    squaw-valley-usa  philip sayles
# 1               1     california    squaw-valley-usa    mateonelson
# 2               2     california    squaw-valley-usa            NaN
# 3               3     california    squaw-valley-usa   Ivan Cazares
# 4               4     california    squaw-valley-usa        welzbob
# ...           ...            ...                 ...            ...
# 18257       18257  new-hampshire  whaleback-mountain       Matthijs
# 18258       18258  new-hampshire  whaleback-mountain          Dolly
# 18259       18259  new-hampshire  whaleback-mountain          Roger
# 18260       18260  new-hampshire  whaleback-mountain         Arthur
# 18261       18261  new-hampshire  whaleback-mountain    David  Cook
#
#               Review Date  Review Star Rating (out of 5)  \
# 0      31st December 2019                              3
# ...

# %%
# Set the first column ('col1') as the index
df = df.drop(df.columns[0], axis=1)  # Drop by index
df
# Out:
#                State            Ski Area  Reviewer Name         Review Date  \
# 0         california    squaw-valley-usa  philip sayles  31st December 2019
# 1         california    squaw-valley-usa    mateonelson       22nd May 2019
# 2         california    squaw-valley-usa            NaN      7th March 2019
# 3         california    squaw-valley-usa   Ivan Cazares      5th March 2019
# 4         california    squaw-valley-usa        welzbob  26th February 2019
# ...              ...                 ...            ...                 ...
# 18257  new-hampshire  whaleback-mountain       Matthijs     18th March 2017
# 18258  new-hampshire  whaleback-mountain          Dolly  25th February 2017
# 18259  new-hampshire  whaleback-mountain          Roger  11th February 2017
# 18260  new-hampshire  whaleback-mountain         Arthur  10th February 2017
# 18261  new-hampshire  whaleback-mountain    David  Cook   4th February 2017
#
#        Review Star Rating (out of 5)  \
# ...

# %%
# impute the missing value in Reviewer Name with anonymous_user
df['Reviewer Name'].fillna("anonymous_user", inplace=True)
df
# Out:
#                State            Ski Area   Reviewer Name         Review Date  \
# 0         california    squaw-valley-usa   philip sayles  31st December 2019
# 1         california    squaw-valley-usa     mateonelson       22nd May 2019
# 2         california    squaw-valley-usa  anonymous_user      7th March 2019
# 3         california    squaw-valley-usa    Ivan Cazares      5th March 2019
# 4         california    squaw-valley-usa         welzbob  26th February 2019
# ...              ...                 ...             ...                 ...
# 18257  new-hampshire  whaleback-mountain        Matthijs     18th March 2017
# 18258  new-hampshire  whaleback-mountain           Dolly  25th February 2017
# 18259  new-hampshire  whaleback-mountain           Roger  11th February 2017
# 18260  new-hampshire  whaleback-mountain          Arthur  10th February 2017
# 18261  new-hampshire  whaleback-mountain     David  Cook   4th February 2017
#
#        Review Star Rating (out of 5)  \
# ...

# %%
df.columns
# Out:
# Index(['State', 'Ski Area', 'Reviewer Name', 'Review Date',
#        'Review Star Rating (out of 5)', 'Review Text'],
#       dtype='object')

# %%
# add a new columns to indicate missing reviews
def generate_review_text_boolean(row):
    if row['Review Text'] is np.nan:
        return 0
    else:
        return 1
    
    
# if row['Review Text'] is np.nan else 0
df['Review Missing']=df.apply(generate_review_text_boolean,axis=1)
df
# Out:
#                State            Ski Area   Reviewer Name         Review Date  \
# 0         california    squaw-valley-usa   philip sayles  31st December 2019
# 1         california    squaw-valley-usa     mateonelson       22nd May 2019
# 2         california    squaw-valley-usa  anonymous_user      7th March 2019
# 3         california    squaw-valley-usa    Ivan Cazares      5th March 2019
# 4         california    squaw-valley-usa         welzbob  26th February 2019
# ...              ...                 ...             ...                 ...
# 18257  new-hampshire  whaleback-mountain        Matthijs     18th March 2017
# 18258  new-hampshire  whaleback-mountain           Dolly  25th February 2017
# 18259  new-hampshire  whaleback-mountain           Roger  11th February 2017
# 18260  new-hampshire  whaleback-mountain          Arthur  10th February 2017
# 18261  new-hampshire  whaleback-mountain     David  Cook   4th February 2017
#
#        Review Star Rating (out of 5)  \
# ...
